# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
df = pd.read_csv('/content/drive/MyDrive/Colab_Notebooks/collegeproject/datasets/crops_final.csv')

# %%
df['crop'].unique()
# Out:
# array(['arhar/tur', 'bajra', 'barley', 'coriander', 'cotton(lint)',
#        'dry chillies', 'gram', 'groundnut', 'jowar', 'linseed', 'maize-k',
#        'maize-r', 'masoor', 'moong(green gram)', 'onion',
#        'peas & beans (pulses)', 'potato', 'ragi', 'rapeseed &mustard',
#        'rice', 'safflower', 'sugarcane', 'sunflower', 'turmeric', 'urad',
#        'wheat', 'garlic', 'cowpea(lobia)', 'ginger'], dtype=object)

# %%
df.columns
# Out:
# Index(['State_Name', 'District_Name', 'Crop_Year', 'Season', 'Area',
#        'Production', 'Temperature', 'PH', 'Rainfall', 'Sowing Temp',
#        'Harvest Temp', 'Phosphorous', 'Nitrogen', 'Potash', 'crop'],
#       dtype='object')

# %%
print(df.dtypes)
# Out:
# State_Name        object
# District_Name     object
# Crop_Year          int64
# Season            object
# Area             float64
# Production       float64
# Temperature      float64
# PH               float64
# Rainfall         float64
# Sowing Temp      float64
# Harvest Temp     float64
# Phosphorous      float64
# Nitrogen         float64
# Potash           float64
# crop              object
# dtype: object

# %%
df.isna().sum()
# Out:
# State_Name          0
# District_Name       0
# Crop_Year           0
# Season              0
# Area                0
# Production       1596
# Temperature         0
# PH                  0
# Rainfall            0
# Sowing Temp         0
# Harvest Temp        0
# Phosphorous         0
# Nitrogen            0
# Potash              0
# crop                0
# dtype: int64

# %%
kar=df.loc[df.State_Name.str.contains("Karnataka",na=False,case=False)]

# %%
kar=kar.dropna(axis=0)

# %%
kar=kar.iloc[:,1:]

# %%
kar
# Out:
#           District_Name  Crop_Year  Season     Area  Production  Temperature  \
# 92              BELGAUM       1997  Kharif  11268.0      1820.0    34.767809
# 93              BELLARY       1997  Kharif  10477.0      3324.0    31.733326
# 94      BENGALURU URBAN       1997  Kharif   6057.0      4131.0    33.873299
# 95                BIDAR       1997  Kharif  48463.0      3499.0    34.391516
# 96              BIJAPUR       1997  Kharif  20286.0      2428.0    33.041521
# ...                 ...        ...     ...      ...         ...          ...
# 120865         GULBARGA       2014    Rabi  14149.0     23751.0    21.853892
# 120866           HAVERI       2014    Rabi    634.0       470.0    25.038176
# 120867           KOPPAL       2014    Rabi   6356.0      8164.0    23.378197
# 120868          RAICHUR       2014    Rabi    656.0       589.0    25.965379
# 120869           YADGIR       2014    Rabi   1080.0      1137.0    23.130433
#
# ...

# %%
kar.isna().sum()
# Out:
# District_Name    0
# Crop_Year        0
# Season           0
# Area             0
# Production       0
# Temperature      0
# PH               0
# Rainfall         0
# Sowing Temp      0
# Harvest Temp     0
# Phosphorous      0
# Nitrogen         0
# Potash           0
# crop             0
# dtype: int64

# %%
kar.to_csv("/content/drive/MyDrive/Colab_Notebooks/collegeproject/datasets/kar_crops.csv",index=False)

# %%
df=pd.read_csv("/content/drive/MyDrive/Colab_Notebooks/collegeproject/datasets/kar_crops.csv")

# %%
df['District_Name'].unique()
# Out:
# array(['BELGAUM', 'BELLARY', 'BENGALURU URBAN', 'BIDAR', 'BIJAPUR',
#        'CHIKMAGALUR', 'CHITRADURGA', 'DHARWAD', 'GULBARGA', 'HASSAN',
#        'KOLAR', 'MANDYA', 'MYSORE', 'RAICHUR', 'SHIMOGA', 'TUMKUR',
#        'UTTAR KANNAD', 'KODAGU', 'BANGALORE RURAL', 'DAKSHIN KANNAD',
#        'BAGALKOT', 'CHAMARAJANAGAR', 'DAVANGERE', 'GADAG', 'HAVERI',
#        'KOPPAL', 'UDUPI', 'CHIKBALLAPUR', 'RAMANAGARA', 'YADGIR'],
#       dtype=object)

# %%
df.columns
# Out:
# Index(['District_Name', 'Crop_Year', 'Season', 'Area', 'Production',
#        'Temperature', 'PH', 'Rainfall', 'Sowing Temp', 'Harvest Temp',
#        'Phosphorous', 'Nitrogen', 'Potash', 'crop'],
#       dtype='object')

# %%
df['crop'].unique()
# Out:
# array(['arhar/tur', 'bajra', 'coriander', 'groundnut', 'jowar', 'maize-k',
#        'maize-r', 'ragi', 'rice', 'sugarcane', 'turmeric', 'wheat',
#        'cotton(lint)', 'dry chillies', 'gram', 'linseed',
#        'moong(green gram)', 'peas & beans (pulses)', 'potato',
#        'safflower', 'sunflower', 'onion', 'rapeseed &mustard', 'urad',
#        'cowpea(lobia)'], dtype=object)

# %%
df=df.iloc[:,[6,7,8,9,10,11,12,13,14]]

# %%
df.columns
# Out:
# Index(['Temperature', 'PH', 'Rainfall', 'Sowing Temp', 'Harvest Temp',
#        'Phosphorous', 'Nitrogen', 'Potash', 'crop'],
#       dtype='object')

# %%
df.shape
# Out:
# (7878, 9)

# %%
cols = ['temperature','ph','rainfall','sowing_temp','harvesting_temp','P','N','K','crop']
df.columns=cols
print("Shape : ",df.shape)
# Out:
# Shape :  (7878, 9)
