# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
df = pd.read_csv('/content/drive/MyDrive/github/collegeproject/datasets/crops_final.csv')

# %%
df_yield=df

# %%
df['crop'].unique()
# Out:
# array(['arhar_tur', 'bajra', 'barley', 'coriander', 'cotton_lint',
#        'dry_chillies', 'gram', 'groundnut', 'jowar', 'linseed', 'maize_k',
#        'maize_r', 'masoor', 'moong_green_gram', 'onion', 'potato', 'ragi',
#        'rapeseed_mustard', 'rice', 'safflower', 'sugarcane', 'sunflower',
#        'turmeric', 'urad', 'wheat', 'garlic', 'cowpea_lobia', 'ginger'],
#       dtype=object)

# %%
# # create Boolean mask for rows containing 'apple'
# mask = df['crop'].str.contains('peas_beans_pulses')

# # drop rows containing 'apple'
# df = df.drop(index=df[mask].index)

# %%
# df['crop'].unique()
# Out:
# array(['arhar_tur', 'bajra', 'barley', 'coriander', 'cotton_lint',
#        'dry_chillies', 'gram', 'groundnut', 'jowar', 'linseed', 'maize_k',
#        'maize_r', 'masoor', 'moong_green_gram', 'onion', 'potato', 'ragi',
#        'rapeseed_mustard', 'rice', 'safflower', 'sugarcane', 'sunflower',
#        'turmeric', 'urad', 'wheat', 'garlic', 'cowpea_lobia', 'ginger'],
#       dtype=object)

# %%
crop_list = [  'arhar',  'bajra',  'barley',   'coriander', 'cottonlint',  'drychillies',
    'bengalgram',  'groundnut',  'jowar',  'linseed',  'maizekharif',  'maizerabi',  'greengram',
      'onion','potato','ragi', 'mustard', 'rice','safflower', 'sugarcane','sunflower',
    'turmeric', 'urad', 'wheat', 'garlic','cowpea']

# %%
df_yield['crop']=df_yield['crop'].replace('arhar_tur','arhar')
df_yield['crop']=df_yield['crop'].replace('gram','bengalgram')
df_yield['crop']=df_yield['crop'].replace("maize_r", "maizerabi")
df_yield['crop']=df_yield['crop'].replace("maize_k", "maizekharif")
df_yield['crop']=df_yield['crop'].replace("dry_chillies", "drychillies")
df_yield['crop']=df_yield['crop'].replace("cotton_lint","cottonlint")
df_yield['crop']=df_yield['crop'].replace("moong_green_gram","greengram")
df_yield['crop']=df_yield['crop'].replace("rapeseed_mustard","mustard")
df_yield['crop']=df_yield['crop'].replace( "cowpea_lobia", "cowpea")

# %%
# df_yield.to_csv('/content/drive/MyDrive/github/collegeproject/datasets/crops_final.csv',index=False)

# %%
df.columns
# Out:
# Index(['State_Name', 'District_Name', 'Crop_Year', 'Season', 'Area',
#        'Production', 'Temperature', 'PH', 'Rainfall', 'Sowing Temp',
#        'Harvest Temp', 'Phosphorous', 'Nitrogen', 'Potash', 'crop'],
#       dtype='object')

# %%
print(df.dtypes)
# Out:
# State_Name        object
# District_Name     object
# Crop_Year          int64
# Season            object
# Area             float64
# Production       float64
# Temperature      float64
# PH               float64
# Rainfall         float64
# Sowing Temp      float64
# Harvest Temp     float64
# Phosphorous      float64
# Nitrogen         float64
# Potash           float64
# crop              object
# dtype: object

# %%
df.isna().sum()
# Out:
# State_Name          0
# District_Name       0
# Crop_Year           0
# Season              0
# Area                0
# Production       1522
# Temperature         0
# PH                  0
# Rainfall            0
# Sowing Temp         0
# Harvest Temp        0
# Phosphorous         0
# Nitrogen            0
# Potash              0
# crop                0
# dtype: int64

# %%
df=df.dropna(axis=0)

# %%
df.isna().sum()
# Out:
# State_Name       0
# District_Name    0
# Crop_Year        0
# Season           0
# Area             0
# Production       0
# Temperature      0
# PH               0
# Rainfall         0
# Sowing Temp      0
# Harvest Temp     0
# Phosphorous      0
# Nitrogen         0
# Potash           0
# crop             0
# dtype: int64

# %%
kar=df.loc[df.State_Name.str.contains("Karnataka",na=False,case=False)]
kar=kar.dropna(axis=0)
kar=kar.iloc[:,1:]
kar.isna().sum()
kar.to_csv("/content/drive/MyDrive/github/collegeproject/datasets/kar_crops.csv",index=False)
kar_crop=pd.read_csv("/content/drive/MyDrive/github/collegeproject/datasets/kar_crops.csv")

# %%
#south states
df['State_Name'].unique()
# Out:
# array(['Andhra Pradesh', 'Assam', 'Bihar', 'Gujarat', 'Karnataka',
#        'Madhya Pradesh', 'Maharashtra', 'Meghalaya', 'Mizoram', 'Punjab',
#        'Rajasthan', 'Telangana', 'Uttar Pradesh', 'Haryana', 'Nagaland',
#        'West Bengal', 'Tamil Nadu', 'Manipur', 'Goa', 'Arunachal Pradesh',
#        'Jammu and Kashmir', 'Odisha', 'Chandigarh',
#        'Dadra and Nagar Haveli', 'Himachal Pradesh', 'Tripura',
#        'Puducherry', 'Sikkim', 'Kerala', 'Chhattisgarh', 'Uttarakhand',
#        'Andaman and Nicobar Islands', 'Jharkhand'], dtype=object)

# %%
south_states=df.loc[((df.State_Name=="Karnataka") |  (df.State_Name=="Andhra Pradesh")
|(df.State_Name=="Telangana") |(df.State_Name=="Tamil Nadu")|(df.State_Name=="Kerala"))]
south_states['State_Name'].unique()
# Out:
# array(['Andhra Pradesh', 'Karnataka', 'Telangana', 'Tamil Nadu', 'Kerala'],
#       dtype=object)

# %%
kar_crop['crop'].unique()
# Out:
# array(['arhar', 'bajra', 'coriander', 'groundnut', 'jowar', 'maizekharif',
#        'maizerabi', 'ragi', 'rice', 'sugarcane', 'turmeric', 'wheat',
#        'cottonlint', 'drychillies', 'bengalgram', 'linseed', 'greengram',
#        'potato', 'safflower', 'sunflower', 'onion', 'mustard', 'urad',
#        'cowpea'], dtype=object)

# %%
south_states=south_states.loc[(south_states.crop!='masoor')]
south_states=south_states.loc[(south_states.crop!='ginger')]

# %%
south_states['crop'].unique()
# Out:
# array(['arhar', 'bajra', 'coriander', 'cottonlint', 'drychillies',
#        'bengalgram', 'groundnut', 'jowar', 'maizekharif', 'maizerabi',
#        'greengram', 'onion', 'potato', 'ragi', 'rice', 'sugarcane',
#        'sunflower', 'turmeric', 'urad', 'wheat', 'linseed', 'safflower',
#        'mustard', 'cowpea'], dtype=object)

# %%
south_states.columns
# Out:
# Index(['State_Name', 'District_Name', 'Crop_Year', 'Season', 'Area',
#        'Production', 'Temperature', 'PH', 'Rainfall', 'Sowing Temp',
#        'Harvest Temp', 'Phosphorous', 'Nitrogen', 'Potash', 'crop'],
#       dtype='object')

# %%
south_states=south_states.reset_index(drop=True)

# %%
# df=df.iloc[:,[6,7,8,9,10,11,12,13,14]]

# %%
south_states.to_csv("/content/drive/MyDrive/github/collegeproject/datasets/south_crops.csv",index=False)

# %%
south_states.columns
# Out:
# Index(['State_Name', 'District_Name', 'Crop_Year', 'Season', 'Area',
#        'Production', 'Temperature', 'PH', 'Rainfall', 'Sowing Temp',
#        'Harvest Temp', 'Phosphorous', 'Nitrogen', 'Potash', 'crop'],
#       dtype='object')

# %%
south_states_crop_class=south_states.iloc[:,[6,7,8,12,11,13,14]]

# %%
south_states_crop_class.columns
# Out:
# Index(['Temperature', 'PH', 'Rainfall', 'Nitrogen', 'Phosphorous', 'Potash',
#        'crop'],
#       dtype='object')

# %%
cols = ['avg_year_temp','ph','rainfall','N','P','K','crop']
south_states_crop_class.columns=cols
print("Shape : ",south_states_crop_class.shape)
# Out:
# Shape :  (19354, 7)

# %%
south_states_crop_class.to_csv("/content/drive/MyDrive/github/collegeproject/datasets/south_crop_class.csv",index=False)
