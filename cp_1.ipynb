# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
df = pd.read_csv('/content/drive/MyDrive/github/collegeproject/datasets/crops_final.csv')

# %%
# df_yield=df

# %%
df['crop'].unique()
# Out:
# array(['arhar_tur', 'bajra', 'barley', 'coriander', 'cotton_lint',
#        'dry_chillies', 'gram', 'groundnut', 'jowar', 'linseed', 'maize_k',
#        'maize_r', 'masoor', 'moong_green_gram', 'onion',
#        'peas_beans_pulses', 'potato', 'ragi', 'rapeseed_mustard', 'rice',
#        'safflower', 'sugarcane', 'sunflower', 'turmeric', 'urad', 'wheat',
#        'garlic', 'cowpea_lobia', 'ginger'], dtype=object)

# %%
# df_yield['crop']=df_yield['crop'].replace('arhar/tur','arhar_tur')
# df_yield['crop']=df_yield['crop'].replace("maize-r", "maize_r")
# df_yield['crop']=df_yield['crop'].replace("maize-k", "maize_k")
# df_yield['crop']=df_yield['crop'].replace("dry chillies", "dry_chillies")
# df_yield['crop']=df_yield['crop'].replace("cotton(lint)","cotton_lint")
# df_yield['crop']=df_yield['crop'].replace("moong(green gram)","moong_green_gram")
# df_yield['crop']=df_yield['crop'].replace("peas & beans (pulses)","peas_beans_pulses")
# df_yield['crop']=df_yield['crop'].replace("rapeseed &mustard","rapeseed_mustard")
# df_yield['crop']=df_yield['crop'].replace( "cowpea(lobia)", "cowpea_lobia")

# %%
# df_yield.to_csv('/content/drive/MyDrive/github/collegeproject/datasets/crops_final.csv',index=False)

# %%
df.columns
# Out:
# Index(['State_Name', 'District_Name', 'Crop_Year', 'Season', 'Area',
#        'Production', 'Temperature', 'PH', 'Rainfall', 'Sowing Temp',
#        'Harvest Temp', 'Phosphorous', 'Nitrogen', 'Potash', 'crop'],
#       dtype='object')

# %%
print(df.dtypes)
# Out:
# State_Name        object
# District_Name     object
# Crop_Year          int64
# Season            object
# Area             float64
# Production       float64
# Temperature      float64
# PH               float64
# Rainfall         float64
# Sowing Temp      float64
# Harvest Temp     float64
# Phosphorous      float64
# Nitrogen         float64
# Potash           float64
# crop              object
# dtype: object

# %%
df.isna().sum()
# Out:
# State_Name          0
# District_Name       0
# Crop_Year           0
# Season              0
# Area                0
# Production       1596
# Temperature         0
# PH                  0
# Rainfall            0
# Sowing Temp         0
# Harvest Temp        0
# Phosphorous         0
# Nitrogen            0
# Potash              0
# crop                0
# dtype: int64

# %%
df=df.dropna(axis=0)

# %%
df.isna().sum()
# Out:
# State_Name       0
# District_Name    0
# Crop_Year        0
# Season           0
# Area             0
# Production       0
# Temperature      0
# PH               0
# Rainfall         0
# Sowing Temp      0
# Harvest Temp     0
# Phosphorous      0
# Nitrogen         0
# Potash           0
# crop             0
# dtype: int64

# %%
kar=df.loc[df.State_Name.str.contains("Karnataka",na=False,case=False)]
kar=kar.dropna(axis=0)
kar=kar.iloc[:,1:]
kar.isna().sum()
kar.to_csv("/content/drive/MyDrive/github/collegeproject/datasets/kar_crops.csv",index=False)
kar_crop=pd.read_csv("/content/drive/MyDrive/github/collegeproject/datasets/kar_crops.csv")

# %%
#south states
df['State_Name'].unique()
# Out:
# array(['Andhra Pradesh', 'Assam', 'Bihar', 'Gujarat', 'Karnataka',
#        'Madhya Pradesh', 'Maharashtra', 'Meghalaya', 'Mizoram', 'Punjab',
#        'Rajasthan', 'Telangana', 'Uttar Pradesh', 'Haryana', 'Nagaland',
#        'West Bengal', 'Tamil Nadu', 'Manipur', 'Goa', 'Arunachal Pradesh',
#        'Jammu and Kashmir', 'Odisha', 'Chandigarh',
#        'Dadra and Nagar Haveli', 'Himachal Pradesh', 'Tripura',
#        'Puducherry', 'Sikkim', 'Kerala', 'Chhattisgarh', 'Uttarakhand',
#        'Andaman and Nicobar Islands', 'Jharkhand'], dtype=object)

# %%
south_states=df.loc[((df.State_Name=="Karnataka") |  (df.State_Name=="Andhra Pradesh")
|(df.State_Name=="Telangana") |(df.State_Name=="Tamil Nadu")|(df.State_Name=="Kerala"))]
south_states['State_Name'].unique()
# Out:
# array(['Andhra Pradesh', 'Karnataka', 'Telangana', 'Tamil Nadu', 'Kerala'],
#       dtype=object)

# %%
kar_crop['crop'].unique()
# Out:
# array(['arhar_tur', 'bajra', 'coriander', 'groundnut', 'jowar', 'maize_k',
#        'maize_r', 'ragi', 'rice', 'sugarcane', 'turmeric', 'wheat',
#        'cotton_lint', 'dry_chillies', 'gram', 'linseed',
#        'moong_green_gram', 'peas_beans_pulses', 'potato', 'safflower',
#        'sunflower', 'onion', 'rapeseed_mustard', 'urad', 'cowpea_lobia'],
#       dtype=object)

# %%
south_states=south_states.loc[(south_states.crop!='masoor')]
south_states=south_states.loc[(south_states.crop!='ginger')]

# %%
south_states['crop'].unique()
# Out:
# array(['arhar_tur', 'bajra', 'coriander', 'cotton_lint', 'dry_chillies',
#        'gram', 'groundnut', 'jowar', 'maize_k', 'maize_r',
#        'moong_green_gram', 'onion', 'potato', 'ragi', 'rice', 'sugarcane',
#        'sunflower', 'turmeric', 'urad', 'wheat', 'linseed',
#        'peas_beans_pulses', 'safflower', 'rapeseed_mustard',
#        'cowpea_lobia'], dtype=object)

# %%
south_states.columns
# Out:
# Index(['State_Name', 'District_Name', 'Crop_Year', 'Season', 'Area',
#        'Production', 'Temperature', 'PH', 'Rainfall', 'Sowing Temp',
#        'Harvest Temp', 'Phosphorous', 'Nitrogen', 'Potash', 'crop'],
#       dtype='object')

# %%
south_states=south_states.reset_index(drop=True)

# %%
# df=df.iloc[:,[6,7,8,9,10,11,12,13,14]]

# %%
south_states.to_csv("/content/drive/MyDrive/github/collegeproject/datasets/south_crops.csv",index=False)

# %%
south_states.columns
# Out:
# Index(['State_Name', 'District_Name', 'Crop_Year', 'Season', 'Area',
#        'Production', 'Temperature', 'PH', 'Rainfall', 'Sowing Temp',
#        'Harvest Temp', 'Phosphorous', 'Nitrogen', 'Potash', 'crop'],
#       dtype='object')

# %%
south_states_crop_class=south_states.iloc[:,[7,8,9,10,11,12,13,14]]

# %%
south_states_crop_class.columns
# Out:
# Index(['PH', 'Rainfall', 'Sowing Temp', 'Harvest Temp', 'Phosphorous',
#        'Nitrogen', 'Potash', 'crop'],
#       dtype='object')

# %%
cols = ['ph','rainfall','sowing_temp','harvesting_temp','P','N','K','crop']
south_states_crop_class.columns=cols
print("Shape : ",south_states_crop_class.shape)
# Out:
# Shape :  (19414, 8)

# %%
south_states_crop_class.to_csv("/content/drive/MyDrive/github/collegeproject/datasets/south_crop_class.csv",index=False)
