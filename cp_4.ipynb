# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import pickle

# %%
df=pd.read_csv('/content/drive/MyDrive/github/collegeproject/datasets/south_crops.csv')

# %%
df.columns
# Out:
# Index(['State_Name', 'District_Name', 'Crop_Year', 'Season', 'Area',
#        'Production', 'avg_year_temp', 'ph', 'rainfall', 'sowing_temp',
#        'harvesting_temp', 'Phosphorous', 'Nitrogen', 'Potash', 'crop'],
#       dtype='object')

# %%
# df = df.rename(columns={'Temperature': 'avg_year_temp','PH':'ph',
#                         'Rainfall':'rainfall','Sowing Temp':'sowing_temp','Harvest Temp':'harvesting_temp'})
# df.to_csv('/content/drive/MyDrive/github/collegeproject/datasets/south_crops.csv',index=False)

# %%
import os
import csv
import pickle
import pandas as pd
from sklearn.tree import DecisionTreeRegressor
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.ensemble import RandomForestRegressor

rear=[]


# Set the path of the folder containing input CSV files
input_folder_path = "/content/drive/MyDrive/github/collegeproject/datasets/unique_crops_south"

# Set the path of the folder to save output pickle files
output_folder_path = "/content/drive/MyDrive/github/collegeproject/pickle_files/crop_yield_south"

# Set the path of the folder to save scaler instances
scaler_folder_path = "/content/drive/MyDrive/github/collegeproject/pickle_files/scalers_crop_yield"

# Loop through all files in the input folder
for filename in os.listdir(input_folder_path):
    if filename.endswith(".csv"):
        file_path = os.path.join(input_folder_path, filename)

        # Load the CSV file as a pandas dataframe
        df = pd.read_csv(file_path)
        # df.drop(['State_Name','PH', 'District_Name','crop', 'Crop_Year'], axis=1, inplace=True)
        # # Convert categorical variable 'Season' to numerical using one-hot encoding
        # df = pd.concat([df, pd.get_dummies(df['Season'])], axis=1)
        # df.drop(['Season'], axis=1, inplace=True)
        # # Prepare the input features and output labels
        # X = df.drop(['Production'], axis=1)
        X=df.iloc[:,[4,6,8]]
        y = df['Production'].values.reshape(-1, 1)
        
        # Scale the data
        scaler = StandardScaler()
        X_scaled = scaler.fit_transform(X)

        # Save the scaler instance as a pickle file
        scaler_file_path = os.path.join(scaler_folder_path, f"{filename}_scaler.pkl")
        with open(scaler_file_path, "wb") as f:
            pickle.dump(scaler, f)
        
        # Split the data into training and testing sets
        x_train, x_test, y_train, y_test = train_test_split(X_scaled, y, test_size=0.2, random_state=2022)

        # Train a Decision Tree Regressor
        regressor=RandomForestRegressor(n_estimators=100,random_state=2022)
        regressor.fit(x_train, y_train)
        
        # Evaluate the model on the test data
        score = regressor.score(x_test, y_test)
        rear.append(score)
        print(f"Filename: {filename}, Score: {score}")
        
        # Save the trained model as a pickle file
        output_file_path = os.path.join(output_folder_path, f"{filename}.pkl")
        with open(output_file_path, "wb") as f:
            pickle.dump(regressor, f)
# Out:
# <ipython-input-25-7b17943f6200>:52: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   regressor.fit(x_train, y_train)
# Filename: crop_arhar_tur.csv, Score: 0.8587070991936144
# <ipython-input-25-7b17943f6200>:52: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   regressor.fit(x_train, y_train)
# Filename: crop_cotton_lint.csv, Score: 0.8839237349531749
# <ipython-input-25-7b17943f6200>:52: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   regressor.fit(x_train, y_train)
# Filename: crop_dry_chillies.csv, Score: 0.5267409817134934
# <ipython-input-25-7b17943f6200>:52: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   regressor.fit(x_train, y_train)
# Filename: crop_gram.csv, Score: 0.8110335792365531
# <ipython-input-25-7b17943f6200>:52: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   regressor.fit(x_train, y_train)
# Filename: crop_maize_k.csv, Score: 0.8328288398033927
# <ipython-input-25-7b17943f6200>:52: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   regressor.fit(x_train, y_train)
# Filename: crop_maize_r.csv, Score: 0.8738544681708494
# <ipython-input-25-7b17943f6200>:52: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   regressor.fit(x_train, y_train)
# Filename: crop_moong_green_gram.csv, Score: 0.5637854908803843
# <ipython-input-25-7b17943f6200>:52: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   regressor.fit(x_train, y_train)
# Filename: crop_rapeseed_mustard.csv, Score: 0.5185304742855747
# <ipython-input-25-7b17943f6200>:52: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   regressor.fit(x_train, y_train)
# Filename: crop_cowpea_lobia.csv, Score: 0.7935492192874477
# <ipython-input-25-7b17943f6200>:52: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   regressor.fit(x_train, y_train)
# Filename: crop_arhar.csv, Score: 0.8587070991936144
# <ipython-input-25-7b17943f6200>:52: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   regressor.fit(x_train, y_train)
# Filename: crop_cottonlint.csv, Score: 0.8839237349531749
# <ipython-input-25-7b17943f6200>:52: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   regressor.fit(x_train, y_train)
# Filename: crop_drychillies.csv, Score: 0.5267409817134934
# <ipython-input-25-7b17943f6200>:52: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   regressor.fit(x_train, y_train)
# Filename: crop_bengalgram.csv, Score: 0.8110335792365531
# <ipython-input-25-7b17943f6200>:52: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   regressor.fit(x_train, y_train)
# Filename: crop_maizekharif.csv, Score: 0.8328288398033927
# <ipython-input-25-7b17943f6200>:52: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   regressor.fit(x_train, y_train)
# Filename: crop_maizerabi.csv, Score: 0.8738544681708494
# <ipython-input-25-7b17943f6200>:52: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   regressor.fit(x_train, y_train)
# Filename: crop_greengram.csv, Score: 0.5637854908803843
# <ipython-input-25-7b17943f6200>:52: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   regressor.fit(x_train, y_train)
# Filename: crop_bajra.csv, Score: 0.6479248621414777
# <ipython-input-25-7b17943f6200>:52: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   regressor.fit(x_train, y_train)
# Filename: crop_mustard.csv, Score: 0.5185304742855747
# Filename: crop_cowpea.csv, Score: 0.7935492192874477
# <ipython-input-25-7b17943f6200>:52: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   regressor.fit(x_train, y_train)
# <ipython-input-25-7b17943f6200>:52: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   regressor.fit(x_train, y_train)
# Filename: crop_jowar.csv, Score: 0.8856645930610954
# <ipython-input-25-7b17943f6200>:52: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   regressor.fit(x_train, y_train)
# Filename: crop_coriander.csv, Score: 0.8368973096821462
# <ipython-input-25-7b17943f6200>:52: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   regressor.fit(x_train, y_train)
# Filename: crop_groundnut.csv, Score: 0.5373350461294834
# <ipython-input-25-7b17943f6200>:52: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   regressor.fit(x_train, y_train)
# Filename: crop_potato.csv, Score: 0.7468516722043751
# <ipython-input-25-7b17943f6200>:52: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   regressor.fit(x_train, y_train)
# Filename: crop_ragi.csv, Score: 0.9045101308213843
# <ipython-input-25-7b17943f6200>:52: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   regressor.fit(x_train, y_train)
# Filename: crop_onion.csv, Score: 0.690082494032852
# <ipython-input-25-7b17943f6200>:52: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   regressor.fit(x_train, y_train)
# Filename: crop_rice.csv, Score: 0.8864308700656843
# <ipython-input-25-7b17943f6200>:52: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   regressor.fit(x_train, y_train)
# Filename: crop_sugarcane.csv, Score: 0.49889534528102764
# <ipython-input-25-7b17943f6200>:52: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   regressor.fit(x_train, y_train)
# Filename: crop_sunflower.csv, Score: 0.8089317555937111
# <ipython-input-25-7b17943f6200>:52: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   regressor.fit(x_train, y_train)
# Filename: crop_turmeric.csv, Score: 0.9112427163219285
# <ipython-input-25-7b17943f6200>:52: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   regressor.fit(x_train, y_train)
# Filename: crop_urad.csv, Score: 0.7955073366858874
# <ipython-input-25-7b17943f6200>:52: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   regressor.fit(x_train, y_train)
# Filename: crop_wheat.csv, Score: 0.8635431051243665
# <ipython-input-25-7b17943f6200>:52: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   regressor.fit(x_train, y_train)
# Filename: crop_linseed.csv, Score: 0.7916993900343108
# <ipython-input-25-7b17943f6200>:52: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   regressor.fit(x_train, y_train)
# Filename: crop_safflower.csv, Score: 0.6748685721585984

# %%
def average(lst):
    total = sum(lst)
    return total / len(lst)
avg = average(rear)
print(avg)
# Out:
# 0.7517058477087061

# %%
dff=pd.read_csv('/content/drive/MyDrive/github/collegeproject/datasets/south_crops.csv')

# %%
dff.columns
# Out:
# Index(['State_Name', 'District_Name', 'Crop_Year', 'Season', 'Area',
#        'Production', 'avg_year_temp', 'ph', 'rainfall', 'sowing_temp',
#        'harvesting_temp', 'Phosphorous', 'Nitrogen', 'Potash', 'crop'],
#       dtype='object')

# %%
test_df=dff.iloc[:,[7,12,11,13,4,8,14,5]]

# %%
x=dff.iloc[:,[4,6,8]]

# %%
x
# Out:
#           Area  avg_year_temp   rainfall
# 0      21400.0      33.259371  60.840858
# 1       6100.0      33.324233  64.758946
# 2       1600.0      33.736284  61.573425
# 3      28400.0      32.341533  63.761790
# 4       5700.0      32.777780  61.350980
# ...        ...            ...        ...
# 19349   2997.0      21.958634  54.604369
# 19350      1.0      23.945774  37.266831
# 19351   1246.0      23.185369  25.192474
# 19352   1196.0      23.588446  30.369903
# 19353    388.0      25.730699  66.788516
#
# [19354 rows x 3 columns]

# %%
y=dff.loc[:,'Production'].values.reshape(-1,1)

# %%
print(x.shape)
print(y.shape)
# Out:
# (19354, 3)
# (19354, 1)

# %%
x_copy=x
x_copy=x_copy.values

# %%
x0=np.ones((19354,1))
x_copy=np.concatenate((x0,x_copy),axis=1)

# %%
from statsmodels.api import OLS
regressor=OLS(y,x_copy).fit()
print(regressor.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.026
# Model:                            OLS   Adj. R-squared:                  0.026
# Method:                 Least Squares   F-statistic:                     171.1
# Date:                Wed, 26 Apr 2023   Prob (F-statistic):          1.68e-109
# Time:                        05:22:06   Log-Likelihood:            -2.8975e+05
# No. Observations:               19354   AIC:                         5.795e+05
# Df Residuals:                   19350   BIC:                         5.795e+05
# Df Model:                           3
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const       1.105e+05   3.17e+04      3.485      0.000    4.84e+04    1.73e+05
# x1             2.7291      0.127     21.463      0.000       2.480       2.978
# x2         -5144.4181   1238.787     -4.153      0.000   -7572.547   -2716.289
# x3          1047.5070    101.940     10.276      0.000     847.696    1247.318
# ==============================================================================
# Omnibus:                    43832.442   Durbin-Watson:                   1.204
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):
# 13230  8.695323   0.000000    40.439885   0.000000     155.0    8.656308
# 10486  8.655369   0.000000    37.695663   0.000000      38.0    7.508031
# 15067  6.660171  10.240983     9.950293   9.631318       1.0  297.294756
# 18710  6.973383  12.060079    32.393938   0.000000   20325.0   66.363514
# 3563   6.837288   5.204745    14.488152   0.000000    3384.0   85.975044
# 2080   6.609941   8.280083     6.186091   8.843193  104588.0   52.873507
# 8029   6.147442  27.745391    39.428303   0.000000    1807.0   47.687432
# 3898   6.513346   0.000000    94.406974   0.000000   16906.0  128.760092
# 2258   6.994243  26.397270    65.302077  12.423396     774.0   70.736095
# 8625   6.699617   3.067485    17.610681   0.000000   12037.0   65.430660
# 13594  6.489447   5.873910    14.451807   0.000000    7178.0   76.294814
# 5314   6.579876  22.184599    51.246251  10.805867      39.0   26.612901
# 12685  6.081870  21.659645    41.929066  21.449445     581.0   65.386546
# 8416   6.314725  18.786644     9.675640   8.316277    2411.0   56.527908
#
#               crop  Production
# 837    drychillies       462.0
# 900     bengalgram        17.0
# 2300     greengram      2122.0
# 13503  maizekharif     36836.0
# 12432    groundnut        42.0
# 7267     greengram     21805.0
# 4732     maizerabi      2138.0
# 3821          rice    100757.0
# 1672         arhar      4978.0
# 4569     groundnut      2290.0
# 7467          ragi         4.0
# 10217    sunflower        57.0
# 15572    groundnut       368.0
# 3073     coriander       321.0
# 16809  maizekharif      4319.0
# 3219   drychillies      2383.0
# 14221   cottonlint     57340.0
# 3339     groundnut     39109.0
# 867     bengalgram     25400.0
# 10898    greengram      2617.0
# 11832       potato        34.0
# 7498       mustard         1.0
# 6837    cottonlint     13700.0
# 18916      linseed       177.0
# 9031     sunflower      3988.0
# 16251    sunflower       122.0
# 16950    greengram       410.0
# 17492    coriander      1342.0
# 14454        jowar      8414.0
# 3261    bengalgram       612.0
# 19043    greengram        12.0
# 3947     sugarcane    555816.0
# 15277        bajra       119.0
# 1926   drychillies      1219.0
# 11190    sugarcane      1228.0
# 4910          ragi        46.0
# 13230    coriander        61.0
# 10486    coriander        21.0
# 15067     turmeric         5.0
# 18710   cottonlint     29075.0
# 3563     greengram      1334.0
# 2080     groundnut    158266.0
# 8029         bajra      2046.0
# 3898     sugarcane   2120012.0
# 2258     maizerabi      2976.0
# 8625     greengram      3190.0
# 13594    greengram      2346.0
# 5314         wheat        27.0
# 12685        onion      5492.0
# 8416         jowar      2343.0

# %%
import pickle
loaded_model=pickle.load(open('/content/drive/MyDrive/github/collegeproject/pickle_files/crop_yield_south/crop_wheat.csv.pkl','rb'))
loaded_scale=pickle.load(open('/content/drive/MyDrive/github/collegeproject/pickle_files/scalers_crop_yield/crop_wheat.csv_scaler.pkl','rb'))
inp=[1631.0,	21.320653,	43.682646		]
data =loaded_scale.transform([inp])
prediction = loaded_model.predict(data)
print(prediction[0])
# Out:
# 1090.56
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
