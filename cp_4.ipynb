# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import pickle

# %%
df=pd.read_csv('/content/drive/MyDrive/github/collegeproject/datasets/unique_crops/crop_onion.csv')

# %%
df.dtypes
# Out:
# crop            object
# Crop_Year        int64
# Area           float64
# Temperature    float64
# Rainfall       float64
# Production     float64
# dtype: object

# %%
df.columns
# Out:
# Index(['crop', 'Crop_Year', 'Area', 'Temperature', 'Rainfall', 'Production'], dtype='object')

# %%
x=df.iloc[:,2:4]

# %%
x
# Out:
#        Area  Temperature
# 0    3614.0    25.291776
# 1      51.0    21.624094
# 2    3905.0    23.673465
# 3    5448.0    23.953389
# 4     137.0    22.928295
# ..      ...          ...
# 170  2142.0    25.354821
# 171    19.0    25.632334
# 172   177.0    25.600453
# 173     1.0    25.055483
# 174    74.0    23.215285
#
# [175 rows x 2 columns]

# %%
y=df.loc[:,'Production'].values.reshape(-1,1)

# %%
print(x.shape)
print(y.shape)
# Out:
# (175, 2)
# (175, 1)

# %%
x_copy=x
x_copy=x_copy.values

# %%
x0=np.ones((175,1))
x_copy=np.concatenate((x0,x_copy),axis=1)

# %%
from statsmodels.api import OLS
regressor=OLS(y,x_copy).fit()
print(regressor.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                      y   R-squared:                       0.675
# Model:                            OLS   Adj. R-squared:                  0.671
# Method:                 Least Squares   F-statistic:                     178.5
# Date:                Sat, 11 Mar 2023   Prob (F-statistic):           1.08e-42
# Time:                        03:51:36   Log-Likelihood:                -2000.9
# No. Observations:                 175   AIC:                             4008.
# Df Residuals:                     172   BIC:                             4017.
# Df Model:                           2
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const       3.993e+04   2.67e+04      1.496      0.136   -1.27e+04    9.26e+04
# ...

# %%
x_copy=x_copy[:,[0,2,3,4]]
regressor=OLS(y,x_copy).fit()
print(regressor.summary())
#if i remove the x feautres further the r square is decreasing.
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-68-6225328ae9c6> in <module>
# ----> 1 x_copy=x_copy[:,[0,2,3,4]]
#       2 regressor=OLS(y,x_copy).fit()
#       3 print(regressor.summary())
#       4 #if i remove the x feautres further the r square is decreasing.
#
# IndexError: index 3 is out of bounds for axis 1 with size 3

# %%
x_copy=x_copy[:,[0,1,2]]
regressor=OLS(y,x_copy).fit()
print(regressor.summary())
#if i remove the x feautres further the r square is decreasing.

# %%
from sklearn.preprocessing import StandardScaler
sc_x=StandardScaler()
sc_y=StandardScaler()
#In standardscaler fit method will calculate the mean and s_d and store it 
#in object sc_x sc_y and transform method is used to standardize the data 
#using the data(mean and sd ) obtanined from fit method;
x=sc_x.fit_transform(x)
y=sc_y.fit_transform(y)

# %%
from sklearn.model_selection import train_test_split as tts
x_train,x_test,y_train,y_test=tts(x,y,random_state=2022,test_size=0.2)

# %%
from sklearn.svm import SVR
regressor=SVR()#by default kernel is rbf hence higher score
regressor.fit(x_train,y_train)
y_pred=regressor.predict(x_test)
regressor.score(x_test,y_test)
# Out:
# /usr/local/lib/python3.9/dist-packages/sklearn/utils/validation.py:1143: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# 0.7890472599102394

# %%
from sklearn.svm import SVR
regressor=SVR(kernel='linear')
regressor.fit(x_train,y_train)
y_pred=regressor.predict(x_test)
regressor.score(x_test,y_test)
# Out:
# /usr/local/lib/python3.9/dist-packages/sklearn/utils/validation.py:1143: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# 0.3344722848439686

# %%
from sklearn.svm import SVR
regressor=SVR(kernel='poly')
regressor.fit(x_train,y_train)
y_pred=regressor.predict(x_test)
regressor.score(x_test,y_test)
# Out:
# /usr/local/lib/python3.9/dist-packages/sklearn/utils/validation.py:1143: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# 0.33258582625171174

# %%
from sklearn.svm import SVR
regressor=SVR(kernel='rbf')
regressor.fit(x_train,y_train)
y_pred=regressor.predict(x_test)
regressor.score(x_test,y_test)
# Out:
# /usr/local/lib/python3.9/dist-packages/sklearn/utils/validation.py:1143: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# 0.7890472599102394

# %%
from sklearn.svm import SVR
regressor=SVR(kernel='rbf',C=12,gamma=0.7)
regressor.fit(x_train,y_train)
y_pred=regressor.predict(x_test)
regressor.score(x_test,y_test)
# Out:
# /usr/local/lib/python3.9/dist-packages/sklearn/utils/validation.py:1143: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# 0.7492336424417094

# %%
from sklearn.tree import DecisionTreeRegressor
regressor=DecisionTreeRegressor()
regressor.fit(x_train,y_train)
ypred= regressor.predict(x_test)
print(regressor.score(x,y))

# %%
from sklearn.ensemble import RandomForestRegressor
regressor=RandomForestRegressor(n_estimators=100,random_state=2022)
regressor.fit(x_train,y_train)
print("Score is ",regressor.score(x,y))
# Out:
# Score is  0.9478645178400822
# <ipython-input-77-695d29518e2b>:3: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   regressor.fit(x_train,y_train)

# %%
df.sample(n=10)
# Out:
#       crop  Crop_Year    Area  Temperature   Rainfall  Production
# 16   onion       1999    15.0    24.779235  72.782196        88.0
# 165  onion       2006  9949.0    23.599156  74.542824     27137.0
# 102  onion       2003  3778.0    23.542873  67.412392      8693.0
# 43   onion       2000   390.0    25.723736  69.627324      2402.0
# 28   onion       2000  4118.0    24.876305  68.935360     29659.0
# 17   onion       1999  1476.0    25.722360  72.983609     22878.0
# 106  onion       2003  3923.0    21.869272  65.657362     23241.0
# 124  onion       2003    75.0    23.993023  74.181792       783.0
# 123  onion       2003     4.0    22.802318  72.671898        42.0
# 147  onion       2004   201.0    23.686270  71.293837      1325.0

# %%
inp=[	917.0	,34.600363	]
inp=sc_x.transform([inp])
y_new=regressor.predict(inp)
y_new_inverse = sc_y.inverse_transform([y_new])
print(y_new_inverse)
# Out:
# [[6189.34]]
# /usr/local/lib/python3.9/dist-packages/sklearn/base.py:420: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
